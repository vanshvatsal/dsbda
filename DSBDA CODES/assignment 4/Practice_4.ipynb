# %%
import pandas as pd

# %%
data = pd.read_csv("fb.csv")

# %%
data.shape
# Out:
# (500, 19)

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.iloc[2:10,:]
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
# 9            139441   Photo         3          12             6         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# ...

# %%
data.iloc[:10,2:5]
# Out:
#    Category  Post Month  Post Weekday
# 0         2          12             4
# 1         2          12             3
# 2         3          12             3
# 3         2          12             2
# 4         2          12             2
# 5         2          12             1
# 6         3          12             1
# 7         3          12             7
# 8         2          12             7
# 9         3          12             6

# %%
data.iloc[:495,:5]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday
# 0              139441   Photo         2          12             4
# 1              139441  Status         2          12             3
# 2              139441   Photo         3          12             3
# 3              139441   Photo         2          12             2
# 4              139441   Photo         2          12             2
# ..                ...     ...       ...         ...           ...
# 490             85979   Photo         3           1             6
# 491             85979   Photo         3           1             6
# 492             85979    Link         1           1             5
# 493             85093   Photo         3           1             1
# 494             85093   Photo         3           1             7
#
# [495 rows x 5 columns]

# %%
data.iloc[:16,1:2]
# Out:
#       Type
# 0    Photo
# 1   Status
# 2    Photo
# 3    Photo
# 4    Photo
# 5   Status
# 6    Photo
# 7    Photo
# 8   Status
# 9    Photo
# 10  Status
# 11   Photo
# 12   Photo
# 13   Photo
# 14   Photo
# 15  Status

# %%
data.iloc[:21,:3]
# Out:
#     Page total likes    Type  Category
# 0             139441   Photo         2
# 1             139441  Status         2
# 2             139441   Photo         3
# 3             139441   Photo         2
# 4             139441   Photo         2
# 5             139441  Status         2
# 6             139441   Photo         3
# 7             139441   Photo         3
# 8             139441  Status         2
# 9             139441   Photo         3
# 10            139441  Status         2
# 11            139441   Photo         2
# 12            139441   Photo         2
# 13            139441   Photo         2
# 14            138414   Photo         2
# 15            138414  Status         2
# 16            138414   Photo         3
# 17            138414   Photo         1
# 18            138414  Status         3
# 19            138414   Photo         3
# 20            138414   Photo         2

# %%
data.iloc[15,:]
# Out:
# Page total likes                                                       138414
# Type                                                                   Status
# Category                                                                    2
# Post Month                                                                 12
# Post Weekday                                                                3
# Post Hour                                                                  10
# Paid                                                                      0.0
# Lifetime Post Total Reach                                               10060
# Lifetime Post Total Impressions                                         19680
# Lifetime Engaged Users                                                   1264
# Lifetime Post Consumers                                                  1209
# Lifetime Post Consumptions                                               1425
# ...

# %%
data.iloc[13:16,:]
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 13            139441   Photo         2          12             5          3
# 14            138414   Photo         2          12             4          5
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 13   0.0                       2549                             4896
# 14   1.0                      22784                            39941
# 15   0.0                      10060                            19680
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# 13                     249                      134
# 14                     887                      337
# 15                    1264                     1209
#
#     Lifetime Post Consumptions  \
# 13                         168
# 14                         417
# 15                        1425
#
# ...

# %%
data.iloc[:,8]
# Out:
# 0       5091
# 1      19057
# 2       4373
# 3      87991
# 4      13594
#        ...
# 495     7536
# 496     6229
# 497     7216
# 498     7564
# 499     7292
# Name: Lifetime Post Total Impressions, Length: 500, dtype: int64

# %%
x = data.iloc[2:10,1:5]

# %%
x
# Out:
#      Type  Category  Post Month  Post Weekday
# 2   Photo         3          12             3
# 3   Photo         2          12             2
# 4   Photo         2          12             2
# 5  Status         2          12             1
# 6   Photo         3          12             1
# 7   Photo         3          12             7
# 8  Status         2          12             7
# 9   Photo         3          12             6

# %%
data.iloc[1:6,[2,4,6,8,10]]
# Out:
#    Category  Post Weekday  Paid  Lifetime Post Total Impressions  \
# 1         2             3   0.0                            19057
# 2         3             3   0.0                             4373
# 3         2             2   1.0                            87991
# 4         2             2   0.0                            13594
# 5         2             1   0.0                            20849
#
#    Lifetime Post Consumers
# 1                     1361
# 2                      113
# 3                      790
# 4                      410
# 5                     1073

# %%
data.iloc[[2,4,6,9],[2,3,4,5]]
# Out:
#    Category  Post Month  Post Weekday  Post Hour
# 2         3          12             3          3
# 4         2          12             2          3
# 6         3          12             1          3
# 9         3          12             6         10

# %%
data.loc[:,["comment","like","share"]]
# Out:
#      comment    like  share
# 0          4    79.0   17.0
# 1          5   130.0   29.0
# 2          0    66.0   14.0
# 3         58  1572.0  147.0
# 4         19   325.0   49.0
# ..       ...     ...    ...
# 495        5    53.0   26.0
# 496        0    53.0   22.0
# 497        4    93.0   18.0
# 498        7    91.0   38.0
# 499        0    91.0   28.0
#
# [500 rows x 3 columns]

# %%
data.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
x=[]
x.extend(range(2,21))
x.extend(range(50,100))
x.extend(range(2,5))
data.iloc[x,5:7]
# Out:
#     Post Hour  Paid
# 2           3   0.0
# 3          10   1.0
# 4           3   0.0
# 5           9   0.0
# 6           3   1.0
# ..        ...   ...
# 98          3   1.0
# 99         10   0.0
# 2           3   0.0
# 3          10   1.0
# 4           3   0.0
#
# [72 rows x 2 columns]

# %%
X = data[['Type','Category','comment','like','share']]
X.head()
# Out:
#      Type  Category  comment    like  share
# 0   Photo         2        4    79.0   17.0
# 1  Status         2        5   130.0   29.0
# 2   Photo         3        0    66.0   14.0
# 3   Photo         2       58  1572.0  147.0
# 4   Photo         2       19   325.0   49.0

# %%
Z = X[X['share']>20]
Z.shape
# Out:
# (230, 5)

# %%
Z = X[(X['share']>25) & (X['like']>20)]
Z.shape
# Out:
# (189, 5)

# %%
Z.to_csv('output.csv',index = False)

# %%
Z.to_html('output.html',index = False)

# %%
newdata = pd.read_csv('newfb.csv')

# %%
newdata.shape
# Out:
# (134, 19)

# %%
  merged = pd.concat([newdata,data])

# %%
merged.shape
# Out:
# (634, 19)

# %%
Y = data.drop(['Type','Category'],axis=1)
Y = data.drop([1,4,5,6])
Y.shape
# Out:
# (496, 19)

# %%
Y = Z.sort_values(by='comment',ascending = False)

# %%
Y.head()
# Out:
#        Type  Category  comment    like  share
# 244   Photo         2      372  5172.0  790.0
# 460   Photo         3      146  1546.0  181.0
# 168   Photo         1      144  1622.0  208.0
# 288   Photo         1      103   469.0   33.0
# 142  Status         2       60   859.0   90.0

# %%
Z.melt()
# Out:
#     variable   value
# 0       Type  Status
# 1       Type   Photo
# 2       Type   Photo
# 3       Type  Status
# 4       Type   Photo
# ..       ...     ...
# 940    share    55.0
# 941    share    41.0
# 942    share    26.0
# 943    share    38.0
# 944    share    28.0
#
# [945 rows x 2 columns]

# %%
Y = pd.get_dummies(Z) # long to wide - no of columns increase
Y
# Out:
#      Category  comment    like  share  Type_Link  Type_Photo  Type_Status  \
# 1           2        5   130.0   29.0      False       False         True
# 3           2       58  1572.0  147.0      False        True        False
# 4           2       19   325.0   49.0      False        True        False
# 5           2        1   152.0   33.0      False       False         True
# 6           3        3   249.0   27.0      False        True        False
# ..        ...      ...     ...    ...        ...         ...          ...
# 493         3       17   185.0   55.0      False        True        False
# 494         3       10   125.0   41.0      False        True        False
# 495         3        5    53.0   26.0      False        True        False
# 498         3        7    91.0   38.0      False        True        False
# 499         2        0    91.0   28.0      False        True        False
#
#      Type_Video
# 1         False
# 3         False
# 4         False
# ...
