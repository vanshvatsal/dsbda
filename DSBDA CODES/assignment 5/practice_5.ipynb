# %%
import pandas as pd

# %%
air = pd.read_csv("airquality.csv")

# %%
air.shape
# Out:
# (153, 7)

# %%
air.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5

# %%
air.count()
# Out:
# Unnamed: 0    153
# Ozone         116
# Solar.R       146
# Wind          153
# Temp          153
# Month         153
# Day           153
# dtype: int64

# %%
air.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64

# %%
air.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind        Temp       Month  \
# count  153.000000  116.000000  146.000000  153.000000  153.000000  153.000000
# mean    77.000000   42.129310  185.931507    9.957516   77.882353    6.993464
# std     44.311398   32.987885   90.058422    3.523001    9.465270    1.416522
# min      1.000000    1.000000    7.000000    1.700000   56.000000    5.000000
# 25%     39.000000   18.000000  115.750000    7.400000   72.000000    6.000000
# 50%     77.000000   31.500000  205.000000    9.700000   79.000000    7.000000
# 75%    115.000000   63.250000  258.750000   11.500000   85.000000    8.000000
# max    153.000000  168.000000  334.000000   20.700000   97.000000    9.000000
#
#               Day
# count  153.000000
# mean    15.803922
# std      8.864520
# min      1.000000
# 25%      8.000000
# 50%     16.000000
# 75%     23.000000
# max     31.000000

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  153 non-null    int64
#  1   Ozone       116 non-null    float64
#  2   Solar.R     146 non-null    float64
#  3   Wind        153 non-null    float64
#  4   Temp        153 non-null    int64
#  5   Month       153 non-null    int64
#  6   Day         153 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 8.5 KB

# %%
A = air.dropna()

# %%
A.shape
# Out:
# (111, 7)

# %%
A
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 6             7   23.0    299.0   8.6    65      5    7
# ..          ...    ...      ...   ...   ...    ...  ...
# 147         148   14.0     20.0  16.6    63      9   25
# 148         149   30.0    193.0   6.9    70      9   26
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [111 rows x 7 columns]

# %%
A = air.fillna(0)

# %%
A
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    0.0      0.0  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    0.0    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
air.fillna(method ='pad')
# Out:
# /var/folders/7w/fhkz_gf905vf1jtzpt1jvt5r0000gn/T/ipykernel_53190/4110873302.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   air.fillna(method ='pad')
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5   18.0    313.0  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150   30.0    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
air.fillna(method='backfill')
# Out:
# /var/folders/7w/fhkz_gf905vf1jtzpt1jvt5r0000gn/T/ipykernel_53190/3196745434.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   air.fillna(method='backfill')
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5   28.0    299.0  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150   14.0    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %%
import numpy as np

# %%
air['Ozone'].replace(np.NaN,air['Ozone'].mean())
# Out:
# 0      41.00000
# 1      36.00000
# 2      12.00000
# 3      18.00000
# 4      42.12931
#          ...
# 148    30.00000
# 149    42.12931
# 150    14.00000
# 151    18.00000
# 152    20.00000
# Name: Ozone, Length: 153, dtype: float64

# %%
air['Ozone'].replace(np.NaN,air['Ozone'].median())
# Out:
# 0      41.0
# 1      36.0
# 2      12.0
# 3      18.0
# 4      31.5
#        ...
# 148    30.0
# 149    31.5
# 150    14.0
# 151    18.0
# 152    20.0
# Name: Ozone, Length: 153, dtype: float64

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(missing_values =np.nan,strategy = 'mean')

# %%
A = imp.fit_transform(air)

# %%
A
# Out:
# array([[  1.,  41., 190., ...,  67.,   5.,   1.],
#        [  2.,  36., 118., ...,  72.,   5.,   2.],
#        [  3.,  12., 149., ...,  74.,   5.,   3.],
#        ...,
#        [151.,  14., 191., ...,  75.,   9.,  28.],
#        [152.,  18., 131., ...,  76.,   9.,  29.],
#        [153.,  20., 223., ...,  68.,   9.,  30.]])
